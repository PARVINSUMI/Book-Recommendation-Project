# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/abc/miniconda3/lib/python3.13/site-packages (1.48.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: packaging<26,>=20 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/abc/miniconda3/lib/python3.13/site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /Users/abc/miniconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/abc/miniconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/abc/miniconda3/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abc/miniconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/abc/miniconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/abc/miniconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abc/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abc/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abc/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abc/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/abc/miniconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/abc/miniconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/abc/miniconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/abc/miniconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /Users/abc/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abc/miniconda3/lib/python3.13/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# ---------------------------
# Load Data
# ---------------------------
@st.cache_data
def load_data():
    df = pd.read_csv("books_clean_data.csv")
    return df

df = load_data()
st.title("📚 Book Recommendation System")

# ---------------------------
# Preprocess
# ---------------------------
# Only use Author, Categories, Publisher
features = ['Author', 'Categories', 'Publisher']

# Make sure columns exist
features = [f for f in features if f in df.columns]

# Fill missing values
for feature in features:
    df[feature] = df[feature].fillna('')

# Combine features into a single text column
df["combined_features"] = df.apply(lambda x: ' '.join([x[f] for f in features]), axis=1)


# TF-IDF vectorization
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df["combined_features"])
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

book_indices = pd.Series(df.index, index=df['Title']).drop_duplicates()

# ---------------------------
# Recommendation Function
# ---------------------------
def get_recommendations(title, cosine_sim=cosine_sim, df=df, indices=book_indices, top_n=5):
    if title not in indices:
        return []
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]  # skip self
    book_indices_list = [i[0] for i in sim_scores]
    return df.iloc[book_indices_list][["Title", "Author", "Categories", "Publisher"]]

# ---------------------------
# Metrics Functions
# ---------------------------
def precision_at_k(recommended, relevant, k=10):
    recommended_k = recommended[:k]
    hits = len(set(recommended_k) & set(relevant))
    return hits / k if k else 0

def recall_at_k(recommended, relevant, k=10):
    recommended_k = recommended[:k]
    hits = len(set(recommended_k) & set(relevant))
    return hits / len(relevant) if relevant else 0

def f1_at_k(recommended, relevant, k=10):
    p = precision_at_k(recommended, relevant, k)
    r = recall_at_k(recommended, relevant, k)
    return 2*p*r / (p+r) if (p+r) else 0

def average_precision(recommended, relevant, k=10):
    score, hits = 0.0, 0
    for i, item in enumerate(recommended[:k], start=1):
        if item in relevant:
            hits += 1
            score += hits / i
    return score / min(len(relevant), k) if relevant else 0

def dcg_at_k(recommended, relevant, k=10):
    dcg = 0.0
    for i, item in enumerate(recommended[:k], start=1):
        if item in relevant:
            dcg += 1 / np.log2(i+1)
    return dcg

def ndcg_at_k(recommended, relevant, k=10):
    dcg = dcg_at_k(recommended, relevant, k)
    idcg = sum(1 / np.log2(i+1) for i in range(1, min(len(relevant), k)+1))
    return dcg / idcg if idcg > 0 else 0

# ---------------------------
# Streamlit Tabs
# ---------------------------
tab1, tab2 = st.tabs(["📖 Recommendations", "📊 Data Insights"])

# ---------------------------
# Tab 1: Recommendations
# ---------------------------
with tab1:
    book_list = df["Title"].dropna().unique()
    selected_book = st.selectbox("📖 Select a book:", book_list)
    top_n = st.slider("How many recommendations?", 1, 10, 5)

    if selected_book:
        st.subheader(f"🔍 Recommendations for: *{selected_book}*")
        recommendations = get_recommendations(selected_book, top_n=top_n)
        st.table(recommendations)

        # Fake relevant items: top 3 from same category
        relevant_books = df[df["Categories"] == df.loc[book_indices[selected_book], "Categories"]]["Title"].head(3).tolist()
        recommended_books = recommendations["Title"].tolist()

        st.subheader("📊 Evaluation Metrics")
        st.write(f"**Precision@{top_n}:** {precision_at_k(recommended_books, relevant_books, top_n):.2f}")
        st.write(f"**Recall@{top_n}:** {recall_at_k(recommended_books, relevant_books, top_n):.2f}")
        st.write(f"**F1@{top_n}:** {f1_at_k(recommended_books, relevant_books, top_n):.2f}")
        st.write(f"**MAP@{top_n}:** {average_precision(recommended_books, relevant_books, top_n):.2f}")
        st.write(f"**NDCG@{top_n}:** {ndcg_at_k(recommended_books, relevant_books, top_n):.2f}")

# ---------------------------
# Tab 2: Data Insights
# ---------------------------
with tab2:
    st.subheader("📊 Top Authors, Publishers, Categories")

    col1, col2 = st.columns(2)

    with col1:
        st.write("**Top 10 Authors**")
        top_authors = df["Author"].value_counts().head(10)
        fig, ax = plt.subplots(figsize=(6,4))
        sns.barplot(y=top_authors.index, x=top_authors.values, palette="viridis", ax=ax)
        st.pyplot(fig)

    with col2:
        st.write("**Top 10 Publishers**")
        top_publishers = df["Publisher"].value_counts().head(10)
        fig, ax = plt.subplots(figsize=(6,4))
        sns.barplot(y=top_publishers.index, x=top_publishers.values, palette="plasma", ax=ax)
        st.pyplot(fig)

    st.write("**Top 10 Categories**")
    top_categories = df["Categories"].value_counts().head(10)
    fig, ax = plt.subplots(figsize=(8,5))
    sns.barplot(y=top_categories.index, x=top_categories.values, palette="cubehelix", ax=ax)
    st.pyplot(fig)

    if "Rating" in df.columns:
        st.write("**Ratings Distribution**")
        fig, ax = plt.subplots(figsize=(8,5))
        sns.histplot(df["Rating"].dropna(), bins=20, kde=True, ax=ax, color="skyblue")
        ax.set_title("Book Ratings Distribution")
        st.pyplot(fig)
# Out:
# 2025-08-22 11:45:00.918 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-08-22 11:45:00.924 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-08-22 11:45:00.925 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.653
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/abc/miniconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-08-22 11:45:01.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.909 Session state does not function when running a script without `streamlit run`
# 2025-08-22 11:45:01.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:01.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /var/folders/j0/mq_mr2hj0hl8xv4kfq895gk40000gn/T/ipykernel_11115/2693404387.py:136: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_authors.index, x=top_authors.values, palette="viridis", ax=ax)
# 2025-08-22 11:45:02.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:02.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /var/folders/j0/mq_mr2hj0hl8xv4kfq895gk40000gn/T/ipykernel_11115/2693404387.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_publishers.index, x=top_publishers.values, palette="plasma", ax=ax)
# 2025-08-22 11:45:02.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /var/folders/j0/mq_mr2hj0hl8xv4kfq895gk40000gn/T/ipykernel_11115/2693404387.py:149: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_categories.index, x=top_categories.values, palette="cubehelix", ax=ax)
# 2025-08-22 11:45:03.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-22 11:45:03.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run Streamlit_book_app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.178.107:8501
#
# /Users/abc/Desktop/Ironhack/Week10/Day1/Project/Streamlit_book_app.py:136: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_authors.index, x=top_authors.values, palette="viridis", ax=ax)
# /Users/abc/Desktop/Ironhack/Week10/Day1/Project/Streamlit_book_app.py:143: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_publishers.index, x=top_publishers.values, palette="plasma", ax=ax)
# /Users/abc/Desktop/Ironhack/Week10/Day1/Project/Streamlit_book_app.py:149: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_categories.index, x=top_categories.values, palette="cubehelix", ax=ax)
